# %% [markdown]
# # Flight Ticket Price Prediction

# %% [markdown]
# #### Group No. - 35
# #### Group Members - Senevirathna G.D.I.U  EG/2020/4207, Jathusan U.  EG/2020/3977

# %% [markdown]
# ### Data Analysis and Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the necessary libraries for our project.

# %%
data = pd.read_csv(r'Clean_Dataset.csv')

# %%
# Importing our dataset which we derived from the KEGGLE website(: https://www.kaggle.com/datasets/shubhambathwal/flight-price-prediction/)

# %%
data.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
# This code shoe  the first 5 rows of our dataset as output. This used to observe the dataset and find any data patterns in processing.

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'airline', 'flight', 'source_city', 'departure_time',
#        'stops', 'arrival_time', 'destination_city', 'class', 'duration',
#        'days_left', 'price'],
#       dtype='object')

# %%
# Give the name of each columns as output.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
# Get the non-null count and data type of each columns.

# %%
data.shape
# Out:
# (300153, 12)

# %%
# Get the details about no of rows and columns in the dataset.

# %%
data.count()
# Out:
# Unnamed: 0          300153
# airline             300153
# flight              300153
# source_city         300153
# departure_time      300153
# stops               300153
# arrival_time        300153
# destination_city    300153
# class               300153
# duration            300153
# days_left           300153
# price               300153
# dtype: int64

# %%
# Show the number of datas in each column.

# %%
data.dtypes
# Out:
# Unnamed: 0            int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# dtype: object

# %%
# Output the data type of each column in the dataset.

# %%
data.describe(include = 'all')
# Out:
#            Unnamed: 0  airline  flight source_city departure_time   stops  \
# count   300153.000000   300153  300153      300153         300153  300153
# unique            NaN        6    1561           6              6       3
# top               NaN  Vistara  UK-706       Delhi        Morning     one
# freq              NaN   127859    3235       61343          71146  250863
# mean    150076.000000      NaN     NaN         NaN            NaN     NaN
# std      86646.852011      NaN     NaN         NaN            NaN     NaN
# min          0.000000      NaN     NaN         NaN            NaN     NaN
# 25%      75038.000000      NaN     NaN         NaN            NaN     NaN
# 50%     150076.000000      NaN     NaN         NaN            NaN     NaN
# 75%     225114.000000      NaN     NaN         NaN            NaN     NaN
# max     300152.000000      NaN     NaN         NaN            NaN     NaN
#
#        arrival_time destination_city    class       duration      days_left  \
# count        300153           300153   300153  300153.000000  300153.000000
# unique            6                6        2            NaN            NaN
# top           Night           Mumbai  Economy            NaN            NaN
# freq          91538            59097   206666            NaN            NaN
# mean            NaN              NaN      NaN      12.221021      26.004751
# std             NaN              NaN      NaN       7.191997      13.561004
# min             NaN              NaN      NaN       0.830000       1.000000
# 25%             NaN              NaN      NaN       6.830000      15.000000
# 50%             NaN              NaN      NaN      11.250000      26.000000
# 75%             NaN              NaN      NaN      16.170000      38.000000
# max             NaN              NaN      NaN      49.830000      49.000000
#
#                 price
# count   300153.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean     20889.660523
# std      22697.767366
# min       1105.000000
# 25%       4783.000000
# 50%       7425.000000
# 75%      42521.000000
# max     123071.000000

# %%
# Describe each columns with the key factors needed for the data preprocesing in the dataset.

# %%
data.isna().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %% [markdown]
# #### There is no null values.

# %%
data.drop(columns = 'Unnamed: 0', inplace = True)

# %%
#Here we are dropping the index column which was "unnamed: 0" in the data set.
# we removed that column because the precense of that column do not influence our required variable(Flight ticket price) 
# so it is better to remove that column

# %%
data.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
  # This will show the first five rows of the dataset. It is used just for the data observation and pattern.

# %%
data.columns
# Out:
# Index(['airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price'],
#       dtype='object')

# %%
plt.figure(figsize = (18,5))
plt.subplot(1,2,1)
sns.histplot(x = 'price', data = data, kde = True)
plt.subplot(1,2,2)
sns.boxplot(x = 'price', data = data)
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# ## Features

# %% [markdown]
# ### Airline

# %%
data['airline'].value_counts()
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64

# %%
# Show the number and the name of occurances in the Airline column

# %%
plt.figure(figsize=(8,9))
plt.subplot(2,1,1)
sns.countplot(x='airline', data=data)
plt.title('Airlines')
plt.subplot(2,1,2)
sns.boxplot(x='airline', y='price', data=data, palette = 'hls')
plt.show()

# %%
# Output the bargraph and the bode plot of the Airline column

# %%
plt.figure(figsize=(8,4))
labels = data['airline'].value_counts().index.tolist()
plt.pie(data['airline'].value_counts(), labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart of Airline')
# Out:
# Text(0.5, 1.0, 'Pie Chart of Airline')

# %%
# Pie chart shows the  frequency distribution of each of the airlines as found above

# %% [markdown]
# ### Flight

# %%
data['flight'].value_counts()
# Out:
# flight
# UK-706     3235
# UK-772     2741
# UK-720     2650
# UK-836     2542
# UK-822     2468
#            ...
# SG-9923       1
# 6E-6474       1
# 6E-865        1
# G8-705        1
# G8-107        1
# Name: count, Length: 1561, dtype: int64

# %% [markdown]
# ### Source_city

# %%
data['source_city'].value_counts()
# Out:
# source_city
# Delhi        61343
# Mumbai       60896
# Bangalore    52061
# Kolkata      46347
# Hyderabad    40806
# Chennai      38700
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,9))
plt.subplot(2,1,1)
sns.countplot(x='source_city', data=data)
plt.title('Source Cities')
plt.subplot(2,1,2)
sns.boxplot(x='source_city', y='price', data=data, palette = 'hls')
plt.show()

# %%
plt.figure(figsize=(8,4))
labels = data['source_city'].value_counts().index.tolist()
plt.pie(data['source_city'].value_counts(), labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart of Source City')
# Out:
# Text(0.5, 1.0, 'Pie Chart of Source City')

# %% [markdown]
# ### Departure_time

# %%
data['departure_time'].value_counts()
# Out:
# departure_time
# Morning          71146
# Early_Morning    66790
# Evening          65102
# Night            48015
# Afternoon        47794
# Late_Night        1306
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,9))
plt.subplot(2,1,1)
sns.countplot(x='departure_time', data=data)
plt.title('Departure Time')
plt.subplot(2,1,2)
sns.boxplot(x='departure_time', y='price', data=data, palette = 'hls')
plt.show()

# %%
plt.figure(figsize=(8,4))
labels = data['departure_time'].value_counts().index.tolist()
plt.pie(data['departure_time'].value_counts(), labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart of Departure Time')
# Out:
# Text(0.5, 1.0, 'Pie Chart of Departure Time')

# %% [markdown]
# ### Stops

# %%
data['stops'].value_counts()
# Out:
# stops
# one            250863
# zero            36004
# two_or_more     13286
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,9))
plt.subplot(2,1,1)
sns.countplot(x='stops', data=data)
plt.title('Stops')
plt.subplot(2,1,2)
sns.boxplot(x='stops', y='price', data=data, palette = 'hls')
plt.show()

# %%
plt.figure(figsize=(8,4))
labels = data['stops'].value_counts().index.tolist()
plt.pie(data['stops'].value_counts(), labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart of Stops')
# Out:
# Text(0.5, 1.0, 'Pie Chart of Stops')

# %% [markdown]
# ### Arrival_time

# %%
data['arrival_time'].value_counts()
# Out:
# arrival_time
# Night            91538
# Evening          78323
# Morning          62735
# Afternoon        38139
# Early_Morning    15417
# Late_Night       14001
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,9))
plt.subplot(2,1,1)
sns.countplot(x='arrival_time', data=data)
plt.title('Arrival times')
plt.subplot(2,1,2)
sns.boxplot(x='arrival_time', y='price', data=data, palette = 'hls')
plt.show()

# %%
plt.figure(figsize=(8,4))
labels = data['arrival_time'].value_counts().index.tolist()
plt.pie(data['arrival_time'].value_counts(), labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart of Arrival times')
# Out:
# Text(0.5, 1.0, 'Pie Chart of Arrival times')

# %% [markdown]
# ### Destination_city

# %%
data['destination_city'].value_counts()
# Out:
# destination_city
# Mumbai       59097
# Delhi        57360
# Bangalore    51068
# Kolkata      49534
# Hyderabad    42726
# Chennai      40368
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,10))
plt.subplot(2,1,1)
sns.boxplot(x='destination_city', y='price', data=data, palette = 'hls')
plt.subplot(2,1,2)
labels = data['destination_city'].value_counts().index.tolist()
plt.pie(data['destination_city'].value_counts(), labels=labels, autopct='%1.1f%%', startangle=90)
plt.show()

# %% [markdown]
# ### Class

# %%
data['class'].value_counts()
# Out:
# class
# Economy     206666
# Business     93487
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,9))
plt.subplot(2,1,1)
sns.boxplot(x='class', y='price', data=data, palette = 'hls')
plt.subplot(2,1,2)
labels = data['class'].value_counts().index.tolist()
plt.pie(data['class'].value_counts(), labels=labels, autopct='%1.1f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d350c7ef50>,
#   <matplotlib.patches.Wedge at 0x1d350ca6150>],
#  [Text(-0.9126236454676102, -0.6140994070453168, 'Economy'),
#   Text(0.9126236454676101, 0.6140994070453172, 'Business')],
#  [Text(-0.49779471570960554, -0.33496331293380915, '68.9%'),
#   Text(0.49779471570960543, 0.3349633129338094, '31.1%')])

# %%
data2=data.groupby(['flight','airline','class'],as_index=False).count()
data2['class'].value_counts()
# Out:
# class
# Economy     1560
# Business     295
# Name: count, dtype: int64

# %% [markdown]
# ### Duration

# %%
data['duration'].value_counts()
# Out:
# duration
# 2.17     4242
# 2.25     4036
# 2.75     2879
# 2.08     2755
# 2.83     2323
#          ...
# 37.17       1
# 38.75       1
# 38.50       1
# 36.25       1
# 41.50       1
# Name: count, Length: 476, dtype: int64

# %% [markdown]
# ### Days_left

# %%
data['days_left'].value_counts()
# Out:
# days_left
# 25    6633
# 18    6602
# 39    6593
# 32    6585
# 26    6573
# 24    6542
# 19    6537
# 31    6534
# 33    6532
# 40    6531
# 41    6525
# 28    6522
# 38    6512
# 20    6502
# 30    6501
# 42    6497
# 22    6494
# 36    6490
# 21    6479
# 37    6476
# 43    6472
# 44    6436
# 17    6419
# 11    6417
# 34    6412
# 13    6404
# 23    6401
# 29    6397
# 12    6381
# 27    6360
# 14    6349
# 15    6340
# 45    6314
# 35    6291
# 16    6272
# 46    6160
# 49    6154
# 48    6078
# 47    6069
# 10    5822
# 8     5767
# 6     5740
# 7     5703
# 9     5665
# 5     5392
# 4     5077
# 3     4248
# 2     4026
# 1     1927
# Name: count, dtype: int64

# %%
len(data['days_left'].value_counts())
# Out:
# 49

# %% [markdown]
# ### Price

# %%
plt.figure(figsize=(15, 3))
sns.boxplot(data=data, x='price')
plt.show()

# %% [markdown]
# ### Encoding Categorical Features

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelBinarizer

# %%
label = LabelEncoder()
data['airline'] = label.fit_transform(data['airline'])
data['source_city'] = label.fit_transform(data['source_city'])
data['departure_time'] = label.fit_transform(data['departure_time'])
data['stops'] = label.fit_transform(data['stops'])
data['arrival_time'] = label.fit_transform(data['arrival_time'])
data['destination_city'] = label.fit_transform(data['destination_city'])
data['class'] = label.fit_transform(data['class'])
data['flight'] = label.fit_transform(data['flight'])

# %%
# Encodinng the needed featues is a must
# As only numerical values in the dataset can be used by the algorithams ,
# encoding is necessary to convert categorical and textual data into a numerical representation,
# that can be used by these algorithms. 
# So we are following this set up to convert other data types into numerical data type.

# %%
data.head()
# Out:
#    airline  flight  source_city  departure_time  stops  arrival_time  \
# 0        4    1408            2               2      2             5
# 1        4    1387            2               1      2             4
# 2        0    1213            2               1      2             1
# 3        5    1559            2               4      2             0
# 4        5    1549            2               4      2             4
#
#    destination_city  class  duration  days_left  price
# 0                 5      1      2.17          1   5953
# 1                 5      1      2.33          1   5953
# 2                 5      1      2.17          1   5956
# 3                 5      1      2.25          1   5955
# 4                 5      1      2.33          1   5955

# %%
data.shape
# Out:
# (300153, 11)

# %% [markdown]
# ### Correlations

# %%
plt.figure(figsize = (18,18))
sns.heatmap(data.corr(), annot = True, cmap = "RdYlGn")

plt.show()

# %% [markdown]
# ### Define X and Y

# %%
X = data.drop(columns = 'price', axis = 1)
Y = data.price

# %% [markdown]
# ### Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler().fit_transform(X)
X = pd.DataFrame(scaler, columns=X.columns)
X.describe().T[['min', 'mean', 'std', '50%', 'max']].style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_a84c5_row0_col0, #T_a84c5_row1_col0, #T_a84c5_row2_col0, #T_a84c5_row3_col0, #T_a84c5_row4_col0, #T_a84c5_row4_col3, #T_a84c5_row5_col0, #T_a84c5_row6_col0, #T_a84c5_row7_col0, #T_a84c5_row8_col0, #T_a84c5_row9_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a84c5_row0_col1 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_a84c5_row0_col2 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_a84c5_row0_col3, #T_a84c5_row6_col3 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_a84c5_row0_col4, #T_a84c5_row1_col4, #T_a84c5_row2_col4, #T_a84c5_row3_col4, #T_a84c5_row4_col4, #T_a84c5_row5_col4, #T_a84c5_row6_col4, #T_a84c5_row7_col3, #T_a84c5_row7_col4, #T_a84c5_row8_col4, #T_a84c5_row9_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a84c5_row1_col1 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_a84c5_row1_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_a84c5_row1_col3 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_a84c5_row2_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_a84c5_row2_col2, #T_a84c5_row3_col2, #T_a84c5_row5_col2, #T_a84c5_row6_col2 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_a84c5_row2_col3, #T_a84c5_row3_col3 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_a84c5_row3_col1 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_a84c5_row4_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_a84c5_row4_col2 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_a84c5_row5_col1 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_a84c5_row5_col3 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_a84c5_row6_col1 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_a84c5_row7_col1 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_a84c5_row7_col2 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_a84c5_row8_col1 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_a84c5_row8_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_a84c5_row8_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_a84c5_row9_col1, #T_a84c5_row9_col3 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_a84c5_row9_col2 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# </style>
# <table id="T_a84c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a84c5_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_a84c5_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_a84c5_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_a84c5_level0_col3" class="col_heading level0 col3" >50%</th>
#       <th id="T_a84c5_level0_col4" class="col_heading level0 col4" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a84c5_level0_row0" class="row_heading level0 row0" >airline</th>
#       <td id="T_a84c5_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_a84c5_row0_col1" class="data row0 col1" >0.620975</td>
#       <td id="T_a84c5_row0_col2" class="data row0 col2" >0.366653</td>
#       <td id="T_a84c5_row0_col3" class="data row0 col3" >0.600000</td>
#       <td id="T_a84c5_row0_col4" class="data row0 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a84c5_level0_row1" class="row_heading level0 row1" >flight</th>
#       <td id="T_a84c5_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_a84c5_row1_col1" class="data row1 col1" >0.697652</td>
#       <td id="T_a84c5_row1_col2" class="data row1 col2" >0.273522</td>
#       <td id="T_a84c5_row1_col3" class="data row1 col3" >0.732051</td>
#       <td id="T_a84c5_row1_col4" class="data row1 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a84c5_level0_row2" class="row_heading level0 row2" >source_city</th>
#       <td id="T_a84c5_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_a84c5_row2_col1" class="data row2 col1" >0.515518</td>
#       <td id="T_a84c5_row2_col2" class="data row2 col2" >0.350352</td>
#       <td id="T_a84c5_row2_col3" class="data row2 col3" >0.400000</td>
#       <td id="T_a84c5_row2_col4" class="data row2 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a84c5_level0_row3" class="row_heading level0 row3" >departure_time</th>
#       <td id="T_a84c5_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_a84c5_row3_col1" class="data row3 col1" >0.483467</td>
#       <td id="T_a84c5_row3_col2" class="data row3 col2" >0.350855</td>
#       <td id="T_a84c5_row3_col3" class="data row3 col3" >0.400000</td>
#       <td id="T_a84c5_row3_col4" class="data row3 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a84c5_level0_row4" class="row_heading level0 row4" >stops</th>
#       <td id="T_a84c5_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_a84c5_row4_col1" class="data row4 col1" >0.142084</td>
#       <td id="T_a84c5_row4_col2" class="data row4 col2" >0.332912</td>
#       <td id="T_a84c5_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_a84c5_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a84c5_level0_row5" class="row_heading level0 row5" >arrival_time</th>
#       <td id="T_a84c5_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_a84c5_row5_col1" class="data row5 col1" >0.614817</td>
#       <td id="T_a84c5_row5_col2" class="data row5 col2" >0.348333</td>
#       <td id="T_a84c5_row5_col3" class="data row5 col3" >0.800000</td>
#       <td id="T_a84c5_row5_col4" class="data row5 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a84c5_level0_row6" class="row_heading level0 row6" >destination_city</th>
#       <td id="T_a84c5_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_a84c5_row6_col1" class="data row6 col1" >0.517661</td>
#       <td id="T_a84c5_row6_col2" class="data row6 col2" >0.348909</td>
#       <td id="T_a84c5_row6_col3" class="data row6 col3" >0.600000</td>
#       <td id="T_a84c5_row6_col4" class="data row6 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a84c5_level0_row7" class="row_heading level0 row7" >class</th>
#       <td id="T_a84c5_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_a84c5_row7_col1" class="data row7 col1" >0.688536</td>
#       <td id="T_a84c5_row7_col2" class="data row7 col2" >0.463093</td>
#       <td id="T_a84c5_row7_col3" class="data row7 col3" >1.000000</td>
#       <td id="T_a84c5_row7_col4" class="data row7 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a84c5_level0_row8" class="row_heading level0 row8" >duration</th>
#       <td id="T_a84c5_row8_col0" class="data row8 col0" >0.000000</td>
#       <td id="T_a84c5_row8_col1" class="data row8 col1" >0.232470</td>
#       <td id="T_a84c5_row8_col2" class="data row8 col2" >0.146775</td>
#       <td id="T_a84c5_row8_col3" class="data row8 col3" >0.212653</td>
#       <td id="T_a84c5_row8_col4" class="data row8 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a84c5_level0_row9" class="row_heading level0 row9" >days_left</th>
#       <td id="T_a84c5_row9_col0" class="data row9 col0" >0.000000</td>
#       <td id="T_a84c5_row9_col1" class="data row9 col1" >0.520932</td>
#       <td id="T_a84c5_row9_col2" class="data row9 col2" >0.282521</td>
#       <td id="T_a84c5_row9_col3" class="data row9 col3" >0.520833</td>
#       <td id="T_a84c5_row9_col4" class="data row9 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (240122, 10)
# (60031, 10)
# (240122,)
# (60031,)

# %%
regressor = LinearRegression()

# %% [markdown]
# ### Cross Validation

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(regressor, x_train, y_train, scoring='r2', cv=kf)
print("Cross-validated R2 scores:", cv_scores)
print("Mean R2 score:", np.mean(cv_scores))
# Out:
# Cross-validated R2 scores: [0.90412562 0.9042197  0.90367092 0.90503911 0.90535558]
# Mean R2 score: 0.9044821851790882

# %%
regressor.fit(x_train, y_train)
predicted = regressor.predict(x_test)
accuracy = metrics.r2_score(y_test, predicted)
score = regressor.score(x_test, y_test)
print("Accuracy: ", accuracy)
score
# Out:
# Accuracy:  0.9051470946813411
# 0.9051470946813411

# %% [markdown]
# #### Hyperparameter Tunning

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'fit_intercept':[True, False], 'copy_X':[True, False], 'positive':[True, False]}

grid_search = GridSearchCV(estimator = regressor, param_grid = parameters, cv = 5)

grid_fit = grid_search.fit(x_train, y_train)

best_model = grid_fit.best_estimator_

best_model.score(x_test, y_test)
# Out:
# 0.9051470946813411

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import scale

Xs = scale(X)
Ys = scale(Y)
x_train, x_test, y_train, y_test = train_test_split(Xs, Ys, test_size=0.2, random_state=2)
sgdr = SGDRegressor(penalty='elasticnet', alpha=0.001, max_iter=100000, tol=1e-6
    , eta0=0.001)
sgdr.fit(x_train, y_train)
predicted = sgdr.predict(x_test)

score = sgdr.score(x_test, y_test)
print(score)
# Out:
# 0.9051161517857848

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, predicted)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 0.20466922291105943

# %%
sns.distplot(y_test-predicted)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15740\712676607.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-predicted)

# %%
plt.scatter(y_test, predicted, alpha = 0.5, color='blue')
#m,c  = np.polyfit(y_test,Y,1)
plt.title('Actual Price  Vs  Predicted Price ')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.show()

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor()
#tree_cv = GridSearchCV(estimator=tree, param_grid=parameters, cv=20).fit(X_train, y_train)
tree.fit(x_train, y_train)

predicts = tree.predict(x_test)
accuracy2 = metrics.r2_score(y_test, predicts)
score = tree.score(x_test, y_test)
print("Accuracy: ", accuracy2)
score
# Out:
# Accuracy:  0.9835078494651914
# 0.9835078494651914

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicts)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 0.0389843996350636

# %%
# param_grid2 = {'criterion':['squared_error', 'poisson', 'friedman_mse', 'absolute_error'], 'splitter':['best', 'random'], 'max_features':[None,8, 7, 6, 5],}
# grid_search2 = GridSearchCV(estimator = tree, param_grid = param_grid2, cv = 20)
# grid_search2.fit(x_train, y_train)
# grid_search2.best_params_

# %%
sns.distplot(y_test-predicts)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15740\2485032210.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-predicts)

# %%
plt.scatter(y_test, predicts, alpha = 0.5, color='red')
#m,c  = np.polyfit(y_test,Y,1)
plt.title('Actual Price  Vs  Predicted Price ')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.show()

# %% [markdown]
# ### Results

# %% [markdown]
# #### Decision tree has maximum accuracy and it is the best model rather than linear regression

# %% [markdown]
# ### Save and Load Model

# %%
import pickle

# %%
with open("regressor_model1.pickle", "wb") as file:
    pickle.dump(regressor, file)

# %%
with open("regressor_model1.pickle", "rb") as file:
    model1 = pickle.load(file)

# %%
model1
# Out:
# LinearRegression()

# %%
import joblib

# %%
joblib.dump(tree, "tree_model2.pickle")
# Out:
# ['tree_model2.pickle']

# %%
model2 = joblib.load("tree_model2.pickle")

# %%
model2
# Out:
# DecisionTreeRegressor()
